# %% [markdown]
# ### Центральная предельная теорема
# В этом задании нужно убедиться, что ЦПТ действительно работает

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
# %matplotlib inline

# %% [markdown]
# Создайте случайную величину из любого выбранного вами распределения, для разных значений n сгенерируйте 1000 выборок размера n и постройте гистрограммы средних этих выборок.

# %%
# зададим нормально распределенную случайную величину
rv = sts.norm(loc=mu, scale=sigma)

# сгенерируем 10 значений
# norm_rv.rvs(size=10)
sample = rv.rvs(size=1000)

# %%
# rv = ### YOUR CODE HERE
lam = 0.1
rv = sts.expon(lam)
# сгенерируем 1000 значений
sample = rv.rvs(size=1000)

# %%
print(f'Среднее значение исходной совокупности равно:{mean(sample)} при объеме выборки: {len(sample)}')
# Out:
# Среднее значение исходной совокупности равно:1.0532506355662996 при объеме выборки: 1000

# %%
x = np.linspace(0,2,100)
pdf = rv.pdf(x)
plt.hist(sample, density=True, bins=30, label='sample histogram')
plt.plot(x, pdf, label='theoretical pdf', alpha=0.5)
plt.legend()
plt.ylabel('fraction of samples, $f(x)$')
plt.xlabel('$x$')
plt.show()

# %%
#параметры запуска: размеры выборок и количество повторов генерации
n1 = 2
# n1 = [2,5,10,20,30,100,1000]
# YOUR CODE HERE
samples_count = 1000
#массивы для сохранения средних по выборкам
a1 = np.array([])

for number in range(samples_count):
    # на каждом цикле генерируем выборки разных размеров
    sample1 = rv.rvs(size=n1)
    mean_i=sum(sample1)/n1#определение выборочного среднего (в.с.)
#     a1=np.append(mean_i)#добавляем в массив новое значение в.с.
    
#     # YOUR CODE HERE
    # считаем среднее по каждой выборке и добавляем в массив средних
    a1 = np.append(a1, sample1.mean())
    # YOUR CODE HERE
    #строим графики
#подписи для графиков
label_1 = 'sample of ' + str(n1) + ' histogram'
plt.hist(a1, density=True, label=label_1)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
from statistics import mean 
print(f'Среднее значение равно:{mean(a1)} при объеме выборки: {n1}')
# Out:
# Среднее значение равно:1.091960613110481 при объеме выборки: 2

# %%
#параметры запуска: размеры выборок и количество повторов генерации
n1 = 10
# n1 = [2,5,10,20,30,100,1000]
# YOUR CODE HERE
samples_count = 1000
#массивы для сохранения средних по выборкам
a1 = np.array([])

for number in range(samples_count):
    # на каждом цикле генерируем выборки разных размеров
    sample1 = rv.rvs(size=n1)
    mean_i=sum(sample1)/n1#определение выборочного среднего (в.с.)
#     a1=np.append(mean_i)#добавляем в массив новое значение в.с.
    
#     # YOUR CODE HERE
    # считаем среднее по каждой выборке и добавляем в массив средних
    a1 = np.append(a1, sample1.mean())
    # YOUR CODE HERE
    #строим графики
#подписи для графиков
label_1 = 'sample of ' + str(n1) + ' histogram'
plt.hist(a1, density=True, label=label_1)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
from statistics import mean 
print(f'Среднее значение равно:{mean(a1)} при объеме выборки: {n1}')
# Out:
# Среднее значение равно:1.1048950442831795 при объеме выборки: 10

# %%
#параметры запуска: размеры выборок и количество повторов генерации
n1 = 100
# n1 = [2,5,10,20,30,100,1000]
# YOUR CODE HERE
samples_count = 1000
#массивы для сохранения средних по выборкам
a1 = np.array([])

for number in range(samples_count):
    # на каждом цикле генерируем выборки разных размеров
    sample1 = rv.rvs(size=n1)
    mean_i=sum(sample1)/n1#определение выборочного среднего (в.с.)
#     a1=np.append(mean_i)#добавляем в массив новое значение в.с.
    
#     # YOUR CODE HERE
    # считаем среднее по каждой выборке и добавляем в массив средних
    a1 = np.append(a1, sample1.mean())
    # YOUR CODE HERE
    #строим графики
#подписи для графиков
label_1 = 'sample of ' + str(n1) + ' histogram'
plt.hist(a1, density=True, label=label_1)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
from statistics import mean 
print(f'Среднее значение равно:{mean(a1)} при объеме выборки: {n1}')
# Out:
# Среднее значение равно:1.1020326414519868 при объеме выборки: 100

# %%
#параметры запуска: размеры выборок и количество повторов генерации
n1 = 1000
# n1 = [2,5,10,20,30,100,1000]
# YOUR CODE HERE
samples_count = 1000
#массивы для сохранения средних по выборкам
a1 = np.array([])

for number in range(samples_count):
    # на каждом цикле генерируем выборки разных размеров
    sample1 = rv.rvs(size=n1)
    mean_i=sum(sample1)/n1#определение выборочного среднего (в.с.)
#     a1=np.append(mean_i)#добавляем в массив новое значение в.с.
    
#     # YOUR CODE HERE
    # считаем среднее по каждой выборке и добавляем в массив средних
    a1 = np.append(a1, sample1.mean())
    # YOUR CODE HERE
    #строим графики
#подписи для графиков
label_1 = 'sample of ' + str(n1) + ' histogram'
plt.hist(a1, density=True, label=label_1)

plt.legend()
plt.ylabel('samples means')
plt.xlabel('$x$')
from statistics import mean 
print(f'Среднее значение равно:{mean(a1)} при объеме выборки: {n1}')
# Out:
# Среднее значение равно:1.1008814681981312 при объеме выборки: 1000
