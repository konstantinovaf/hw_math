# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts

# %matplotlib inline

# %% [markdown]
# ### Задание 1
#
# Получить интуицию, на что влияют параметры распределений. Построить по 5 функций плотностей с разными параметрами для каждого распределения: нормальное, экспоненциальное, Стьюдента на одном графике.

# %%
# Построить по 5 функций плотностей с разными параметрами для каждого распределения:
# нормальное,
# pdf(x, loc=0, scale=1) - Probability density function.
mu = [1, 2.0, 3]
sigma = [0.2, 0.5]
# зададим нормально распределенную случайную величину
# norm_rv = sts.norm(loc=mu[0], scale=sigma[0])

norm_rv1 = sts.norm(loc=mu[0], scale=sigma[0])
norm_rv2 = sts.norm(loc=mu[1], scale=sigma[0])
norm_rv3 = sts.norm(loc=mu[2], scale=sigma[0])
norm_rv4 = sts.norm(loc=mu[0], scale=sigma[1])
norm_rv5 = sts.norm(loc=mu[1], scale=sigma[1])
norm_rv6 = sts.norm(loc=mu[2], scale=sigma[1])

# %%
# Рисуем 5 графиков
# [left, bottom, width, height]
x = np.linspace(0,4,100)

ax1 = plt.axes([0.1, 0.6, 0.2, 0.35])  # standard axes
ax2 = plt.axes([0.4, 0.6, 0.2, 0.35])  # standard axes
ax3 = plt.axes([0.7, 0.6, 0.2, 0.35])  # standard axes
ax4 = plt.axes([0.1, 0.1, 0.2, 0.35])  # standard axes
ax5 = plt.axes([0.4, 0.1, 0.2, 0.35])  # standard axes
ax6 = plt.axes([0.7, 0.1, 0.2, 0.35])  # standard axes
ax1.plot(x, norm_rv1.pdf(x))
ax2.plot(x, norm_rv2.pdf(x))
ax3.plot(x, norm_rv3.pdf(x))
ax4.plot(x, norm_rv4.pdf(x))
ax5.plot(x, norm_rv5.pdf(x))
# ax6.plot(x, norm_rv6.pdf(x))

# %%
# экспоненциальное
# lam = 0.2
lam = [0, 0.1,0.25, 0.5,3]

expon_rv = sts.expon(lam)
expon_rv1 = sts.expon(lam[0])
expon_rv2 = sts.expon(lam[1])
expon_rv3 = sts.expon(lam[2])
expon_rv4 = sts.expon(lam[3])
expon_rv5 = sts.expon(lam[4])

ax1 = plt.axes([0.1, 0.6, 0.2, 0.35])  # standard axes
ax2 = plt.axes([0.4, 0.6, 0.2, 0.35])  # standard axes
ax3 = plt.axes([0.7, 0.6, 0.2, 0.35])  # standard axes
ax4 = plt.axes([0.1, 0.1, 0.2, 0.35])  # standard axes
ax5 = plt.axes([0.4, 0.1, 0.2, 0.35])  # standard axes
# ax6 = plt.axes([0.7, 0.1, 0.2, 0.35])  # standard axes

ax1.plot(x, expon_rv1.pdf(x))
ax2.plot(x, expon_rv2.pdf(x))
ax3.plot(x, expon_rv3.pdf(x))
ax4.plot(x, expon_rv4.pdf(x))
ax5.plot(x, expon_rv5.pdf(x))

# # expon_rv.rvs(10)
# x = np.linspace(0,5,100)
# pdf = expon_rv.pdf(x)
# plt.plot(x, pdf)

# plt.ylabel('$F(x)$')
# plt.xlabel('$x$')
# plt.show()

# %%
# Стьюдента
n = [0,0.1,0.5,1,10]

t_rv1 = sts.t(n[0])
t_rv2= sts.t(n[1])
t_rv3 = sts.t(n[2])
t_rv4 = sts.t(n[3])
t_rv5 = sts.t(n[4])

ax1 = plt.axes([0.1, 0.6, 0.2, 0.35])  # standard axes
ax2 = plt.axes([0.4, 0.6, 0.2, 0.35])  # standard axes
ax3 = plt.axes([0.7, 0.6, 0.2, 0.35])  # standard axes
ax4 = plt.axes([0.1, 0.1, 0.2, 0.35])  # standard axes
ax5 = plt.axes([0.4, 0.1, 0.2, 0.35])  # standard axes

x = np.linspace(-5,5,100)

ax1.plot(x, t_rv1.pdf(x))
ax2.plot(x, t_rv2.pdf(x))
ax3.plot(x, t_rv3.pdf(x))
ax4.plot(x, t_rv4.pdf(x))
ax5.plot(x, t_rv5.pdf(x))

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Непрерывная случайная величина задана плотностью распределения:
# $$ f(\xi) = C, x \in [0;5];
# f(\xi) = 0, x \notin [0;5]$$
# Найдите C, математическое ожидание $\xi$ а также вероятность попадания $\xi$ в отрезок $[3.5;7]$, т.е. $P(3.5<\xi<7)$.

# %%
# https://ru.wikipedia.org/wiki/%D0%9F%D0%BB%D0%BE%D1%82%D0%BD%D0%BE%D1%81%D1%82%D1%8C_%D0%B2%D0%B5%D1%80%D0%BE%D1%8F%D1%82%D0%BD%D0%BE%D1%81%D1%82%D0%B8
#1.  Свойство плотности распределения от минус бесконечности до бесконечности интеграл = 1
# Так как функция плотности распределения определена только на отрезке [0;5] и равна С, то С=1

# 2. Математическое ожидание  ξ 
# среднее значение случайной величины
#  Eeps=интеграл(-inf, inf)x*c*dx=0
    
# 3. Вероятность попадания eps в отрезок [3.5;7], так как функция не определена на интервале больше 5, то считаем интеграл от 3,5 до 5.
# P(3.5<eps<7)=P(3.5<eps<5)=f(5)-f(3.5)=
# Вариант 1 (основной)
# что f(x)=c - константа, значит это равномерное распределение.
# И чтобы получить 1 суммарно на отрезке [0,5], вероятность по нему равномерно распределена
# Если берем вероятность попадания на отрезок [3.5,5], то вероятность будет равна (5-3,5)/5=0,3

# Вариант 2 (берем интеграл в прямом виде) Интеграл(3.5,5)*1*dx
# Первообразная = x. f(5)-f(3.5)=5-3.5=1.5 - сомнительный, потому как вероятность > 1

# %% [markdown]
# ### Задание 3
# Известно, что светофор горит 54 секунды красным, 4 секунды жёлтым и 28 секунд зелёным. Посчитайте, какое количество информации несёт сообщение о цвете светофора в текущий момент. А что будет в случае 28, 28 и 28 секунд для каждого цвета?

# %%
# http://mathprofi.ru/ravnomernoe_raspredelenie_veroyatnostei.html
# какое количество информации несёт сообщение о цвете светофора в текущий момент. 
import math
# H(x)=-sum(p_i*log2(p_i))
# сумма цикла светофора
# sum_sv=54+4+28=86

p_kr=54/86
p_zh=4/86
p_zl=28/86
H=-(p_kr*math.log(p_kr, 2)+p_zh*math.log(p_zh, 2)+p_zl*math.log(p_zl, 2))
print(f'Количество информации в сообщении о цвете светофора в текущий момент (54с-красный, 4с - желтый, 28с - зеленый): {round(H, 4)}')
# А что будет в случае 28, 28 и 28 секунд для каждого цвета?
# P=1/3 - равная вероятность любого события
# I=log2*N^-1=log2(1/(1/3))=1.585
print(f'Количество информации в сообщении о цвете светофора в текущий момент (28с-красный, 28с - желтый, 28с - зеленый): {round(I,4)}')
# Out:
# Количество информации в сообщении о цвете светофора в текущий момент (54с-красный, 4с - желтый, 28с - зеленый): 1.1545
# Количество информации в сообщении о цвете светофора в текущий момент (28с-красный, 28с - желтый, 28с - зеленый): 1.585
